# %%
import pandas as pd
import numpy as np

# %%
customers= pd.read_csv("olist_customers_dataset.csv")
geolocation=pd.read_csv("olist_geolocation_dataset.csv")
items=pd.read_csv("olist_order_items_dataset.csv")
payments=pd.read_csv("olist_order_payments_dataset.csv")
reviews=pd.read_csv("olist_order_reviews_dataset.csv")
reviews=pd.read_csv("olist_order_reviews_dataset.csv")
orders=pd.read_csv("olist_orders_dataset.csv")
products=pd.read_csv("olist_products_dataset.csv")
sellers=pd.read_csv("olist_sellers_dataset.csv")
category=pd.read_csv("product_category_name_translation.csv")

# %%
geol=geolocation.copy()
zip_codes = list(customers["customer_zip_code_prefix"])
geol[geol["geolocation_zip_code_prefix"].isin(zip_codes)]
geol.shape
geolocation.shape
# Out:
# (1000163, 5)

# %%
df_1= reviews.merge(orders,left_on = "order_id", right_on = "order_id",
                          how="inner")
df_2= df_1.merge(payments,left_on = "order_id", right_on = "order_id",
                          how="inner")
df_3= df_2.merge(customers,left_on = "customer_id", right_on = "customer_id",
                          how="inner")
df_4= df_3.merge(items,left_on = "order_id", right_on = "order_id",
                          how="inner")
df_5= df_4.merge(products,left_on = "product_id", right_on = "product_id",
                          how="inner")
df_6= df_5.merge(sellers,left_on = "seller_id", right_on = "seller_id",
                          how="inner")
df_6.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  e2655da8bccce2ddc2f43cc2c80d24f3  19721d59a9764437477eff0730b48665
# 3  cb18f53b563f0bdeb76be0376ddd6b6a  efd626e6a12a82d76e456e34093f8356
# 4  5fdb2ed7aa0f1b1c9642175b302e38af  b0bc656fed47584c160f8cff2d7b8bbd
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             4                  NaN                    NaN
# 2             5                  NaN                    NaN
# 3             5                  NaN                    NaN
# 4             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp  \
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-01-18 00:00:00     2018-01-18 21:46:59
# ...

# %%
df_6.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp', 'customer_id', 'order_status',
#        'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'product_category_name',
#        'product_name_lenght', 'product_description_length',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state'],
#       dtype='object')

# %%
df_6.shape
# Out:
# (118315, 39)

# %%
df_6.describe()
# Out:
#         review_score  payment_sequential  payment_installments  payment_value  \
# count  118315.000000       118315.000000         118315.000000  118315.000000
# mean        4.014554            1.094062              2.943498     172.575651
# std         1.400186            0.728555              2.778022     267.104661
# min         1.000000            1.000000              0.000000       0.000000
# 25%         3.000000            1.000000              1.000000      60.850000
# 50%         5.000000            1.000000              2.000000     108.200000
# 75%         5.000000            1.000000              4.000000     189.260000
# max         5.000000           29.000000             24.000000   13664.080000
#
#        customer_zip_code_prefix  order_item_id          price  freight_value  \
# count             118315.000000  118315.000000  118315.000000  118315.000000
# mean               35051.681579       1.196509     120.651027      20.033024
# ...

# %%
import math
x=df_6[df_6['review_comment_title'].isnull()==False]
x[['review_score', 'review_comment_title',
       'review_comment_message', 'review_creation_date',
       'review_answer_timestamp','product_category_name']]
# Out:
#         review_score       review_comment_title  \
# 20                 5             Antes do Prazo
# 23                 4                  Recomendo
# 29                 3  Não veio o produto total
# 30                 3  Não veio o produto total
# 179                1        cancelamento compra
# ...              ...                        ...
# 118283             5               Recomendo!!!
# 118291             3      Atendimento Prestado
# 118296             5                  Excelente
# 118299             5                RECOMENDADO
# 118310             4                  recomendo
#
#                                    review_comment_message  \
# 20                     Entregue antes do prazo. Perfeito!
# 23                                                    NaN
# 29                  Comprei 2 produtos e recebi apenas 1
# 30                  Comprei 2 produtos e recebi apenas 1
# 179     Foi cancelado a compra antes da emissão de not...
# ...
